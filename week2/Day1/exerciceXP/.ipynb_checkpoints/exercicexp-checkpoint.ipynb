# %% [markdown]
#  #exercice1
#
#  Introduction à l’analyse des données
#
#  Qu’est-ce que l’analyse de données ?
#
# L’analyse de données est le processus qui consiste à collecter, nettoyer, transformer et interpréter des données dans le but d’en extraire des informations utiles. Elle permet de comprendre des phénomènes, d’identifier des tendances et de soutenir la prise de décision. Grâce à des outils comme Python, Pandas ou encore des techniques statistiques, les données brutes sont transformées en informations exploitables.
#
# ---
#
#  Pourquoi l’analyse des données est-elle importante ?
#
# Dans le monde moderne, l’analyse des données joue un rôle essentiel dans presque tous les secteurs. Elle permet aux entreprises et aux organisations de prendre des décisions basées sur des faits plutôt que sur des intuitions.
#
# Son importance se manifeste à plusieurs niveaux :
#
# * **Prise de décision éclairée** : les données permettent de réduire les incertitudes
# * **Optimisation des performances** : amélioration des processus et des résultats
# * **Anticipation des tendances** : capacité à prévoir les évolutions futures
# * **Personnalisation des services** : adaptation aux besoins des utilisateurs
#
# Ainsi, l’analyse des données est devenue un levier stratégique incontournable.
#
# ---
#
#  Domaines d’application de l’analyse de données
#
# 1. Santé
#
# Dans le domaine médical, l’analyse des données permet de prédire les maladies, d’améliorer les diagnostics et d’optimiser les traitements. Par exemple, l’analyse des données de patients aide à détecter plus rapidement certaines pathologies et à suivre l’évolution des épidémies.
#
# 2. Finance
#
# Dans le secteur financier, elle est utilisée pour détecter les fraudes, analyser les risques et améliorer les investissements. Les banques utilisent des modèles d’analyse pour évaluer la solvabilité des clients et sécuriser les transactions.
#
# 3. Marketing et commerce
#
# Les entreprises utilisent l’analyse de données pour comprendre le comportement des consommateurs, personnaliser les offres et améliorer l’expérience client. Cela permet d’augmenter les ventes et de fidéliser les clients.
#
# ---
#
# 🧾 Conclusion
#
# L’analyse des données est aujourd’hui au cœur des innovations technologiques et des stratégies d’entreprise. Elle permet de transformer des données en connaissances, facilitant ainsi la prise de décision et la résolution de problèmes. Dans un monde de plus en plus numérique, maîtriser l’analyse de données constitue une compétence essentielle et un véritable avantage конкурентiel.

# %%
#exercice 2 

import pandas as pd
df_sleep = pd.read_csv('C:/Users/hp/Desktop/DI_BOOTCAMP/week2/Day1/exerciceXP/Time Americans Spend Sleeping.csv')
df_mental_health = pd.read_csv('C:/Users/hp/Desktop/DI_BOOTCAMP/week2/Day1/exerciceXP/Mental health Depression disorder Data.csv')
df_credit = pd.read_csv('C:/Users/hp/Desktop/DI_BOOTCAMP/week2/Day1/exerciceXP/clean_dataset.csv')

# Affichage des premières lignes pour valider
print("--- 1. SOMMEIL ---")
print(df_sleep.head(3))

print("\n--- 2. SANTÉ MENTALE ---")
print(df_mental_health.head(3))

print("\n--- 3. CARTES DE CRÉDIT ---")
print(df_credit.head(3))
# Out:
# --- 1. SOMMEIL ---
#    index  Year  Period  Avg hrs per day sleeping  Standard Error Type of Days  \
# 0      0  2003  Annual                      8.57           0.018     All days
# 1      1  2004  Annual                      8.55           0.026     All days
# 2      2  2005  Annual                      8.62           0.023     All days
#
#            Age Group  Activity   Sex
# 0  15 years and over  Sleeping  Both
# 1  15 years and over  Sleeping  Both
# 2  15 years and over  Sleeping  Both
#
# --- 2. SANTÉ MENTALE ---
#    index       Entity Code  Year Schizophrenia (%) Bipolar disorder (%)  \
# 0      0  Afghanistan  AFG  1990           0.16056             0.697779
# 1      1  Afghanistan  AFG  1991          0.160312             0.697961
# 2      2  Afghanistan  AFG  1992          0.160135             0.698107
#
#   Eating disorders (%)  Anxiety disorders (%)  Drug use disorders (%)  \
# 0             0.101855               4.828830                1.677082
# ...

# %% [markdown]
# Sommeil (df_sleep) : Analyse le temps de sommeil des Américains selon leur âge, stress et mode de vie.Santé Mentale (df_mental_health) : Mesure le pourcentage de dépression et d'anxiété par pays et par année.
# Cartes de Crédit (df_credit) : Regroupe les données financières des clients pour prédire l'accord d'une carte.Premières lignes : L'affichage .head(3) confirme le bon chargement et montre la

# %%
#exercice3 

print("Colonnes Sommeil :", df_sleep.columns.tolist())
print("Colonnes Santé Mentale :", df_mental_health.columns.tolist())
print("Colonnes Crédit :", df_credit.columns.tolist())
# Out:
# Colonnes Sommeil : ['index', 'Year', 'Period', 'Avg hrs per day sleeping', 'Standard Error', 'Type of Days', 'Age Group', 'Activity', 'Sex']
# Colonnes Santé Mentale : ['index', 'Entity', 'Code', 'Year', 'Schizophrenia (%)', 'Bipolar disorder (%)', 'Eating disorders (%)', 'Anxiety disorders (%)', 'Drug use disorders (%)', 'Depression (%)', 'Alcohol use disorders (%)']
# Colonnes Crédit : ['Gender', 'Age', 'Debt', 'Married', 'BankCustomer', 'Industry', 'Ethnicity', 'YearsEmployed', 'PriorDefault', 'Employed', 'CreditScore', 'DriversLicense', 'Citizen', 'ZipCode', 'Income', 'Approved']

# %% [markdown]
#  Jeu de données : Sommeil (df_sleep)
#
#  Colones Quantitatives : Heures de sommeil, Âge, Niveau de stress, Consommation de caféine.Raisonnement : Ce sont des valeurs numériques mesurables sur lesquelles on peut faire des calculs mathématiques (comme une moyenne ou une somme).
#  Colonnes Qualitatives : Profession, Genre, Qualité du sommeil (si catégories textuelles comme "Bonne/Mauvaise").Raisonnement : Ce sont des catégories textuelles, des étiquettes ou des descriptions non numériques qui servent à classer les individus.
#
#  Jeu de données : Santé Mentale (df_mental_health)
#  Colonnes Quantitatives : Année, Pourcentage de dépression, Pourcentage d'anxiété, Taux de schizophrénie.Raisonnement : Ces données décrivent des mesures précises de temps ou des taux d'évolution numériques.
#  Colonnes Qualitatives : Nom du pays (Entity), Code pays (Code).Raisonnement : Ce sont des identifiants et des noms géographiques qui segmentent les données par régions.
#
#  Jeu de données : Cartes de Crédit (df_credit)
#  Colonnes Quantitatives : Revenu annuel, Âge, Nombre d'enfants, Ancienneté dans l'emploi.Raisonnement : Il s'agit de montants financiers ou de décomptes numériques mesurables.
#  Colonnes Qualitatives : Genre, Statut d'emploi, Niveau d'éducation, Statut de la demande (Approuvé/Refusé).Raisonnement : Ce sont des caractéristiques sociales, professionnelles ou des décisions logiques qui décrivent le profil d'un client.Voulez-vous que l'on vérifie s'il y a des variables numériques qui cachent en fait des catégories (comme des codes 0 ou 1) dans votre fichier de cartes de crédit ?

# %%
#exercice4

import pandas as pd

# Chargement du jeu de données Iris (ajustez le nom exact du fichier si nécessaire)
df_iris = pd.read_csv('C:/Users/hp/Desktop/DI_BOOTCAMP/week2/Day1/exerciceXP/Iris.csv')

# Affichage des colonnes et des 3 premières lignes
print("--- APERÇU DU JEU DE DONNÉES IRIS ---")
display(df_iris.head(3))
# Out:
# --- APERÇU DU JEU DE DONNÉES IRIS ---
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa

# %% [markdown]
# Classification des colonnes :Le jeu de données Iris contient généralement les colonnes suivantes :
# Colonnes Quantitatives : SepalLengthCm (Longueur du sépale), SepalWidthCm (Largeur du sépale), PetalLengthCm (Longueur du pétale), PetalWidthCm (Largeur du pétale).
#
# Colonnes Qualitatives : Species (Espèce de la fleur).Note sur la colonne Id : Si votre fichier contient une colonne Id, elle est considérée comme qualitative (c'est un simple identifiant/nom de ligne, pas une mesure).
#
#  Raisonnement et justification : Pourquoi les dimensions (Sépales et Pétales) sont quantitatives ? Ce sont des variables numériques continues mesurées en centimètres. Elles représentent des grandeurs physiques réelles sur lesquelles il est mathématiquement logique de calculer des moyennes, des médianes ou des écarts-types.Pourquoi l'espèce (Species) est qualitative ?C'est une variable textuelle nominale qui sert d'étiquette. Elle classe chaque fleur dans une catégorie distincte (par exemple : Iris-setosa, Iris-versicolor, Iris-virginica) et ne

# %%
#exercice5

import pandas as pd
df_sleep = pd.read_csv('C:/Users/hp/Desktop/DI_BOOTCAMP/week2/Day1/exerciceXP/Time Americans Spend Sleeping.csv')
df_sleep.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 945 entries, 0 to 944
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   index                     945 non-null    int64
#  1   Year                      945 non-null    int64
#  2   Period                    945 non-null    object
#  3   Avg hrs per day sleeping  945 non-null    float64
#  4   Standard Error            945 non-null    float64
#  5   Type of Days              945 non-null    object
#  6   Age Group                 945 non-null    object
#  7   Activity                  945 non-null    object
#  8   Sex                       945 non-null    object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 66.6+ KB

# %% [markdown]
# #exercice6
#
# Les rapports financiers d'une entreprise sont stockés dans un fichier Excel. Donnees structurees
#
# Photographies téléchargées sur une plateforme de médias sociaux. Donnees non-structurees
#
# Une collection d'articles de presse sur un site web. Donnees structurees
#
# Données d'inventaire dans une base de données relationnelle. Donnees structurees
#
# Enregistrements d'entretiens issus d'une étude de marché. Donnes structurées

# %% [markdown]
# #exercice7
#
# Une série d'articles de blog sur les expériences de voyageMéthode de transformation :
#
# Le Traitement du Langage Naturel (NLP) combiné à de l'Extraction d'Entités Nommées (NER)
# Format structuré obtenu : Un tableau (DataFrame) avec les colonnes
#
# Justification : Les articles de blog contiennent beaucoup de texte libre. Les algorithmes NLP permettent de scanner le texte pour repérer automatiquement les mots-clés importants (comme les noms de pays ou les prix) et les ranger dans des cases propres.
#
# Enregistrements audio des appels au service clientMéthode de transformation : Une technologie de reconnaissance vocale Speech-to-Text , suivie d'une analyse de sentiment.Format structuré obtenu : Un tableau avec les colonnes :
#
# Justification : Le son n'est pas exploitable directement par Pandas. Il faut obligatoirement convertir la voix en texte d'abord, puis appliquer des filtres pour classer les appels par motif et détecter le niveau de satisfaction des clients.
#
#  Notes manuscrites issues d'une séance de brainstormingMéthode de transformation : La Reconnaissance Optique de Caractères (OCR) intelligente  couplée à une classification par grappes (Clustering / Tags).Format structuré obtenu : Un tableau avec les colonnes :
# .Justification : Les notes manuscrites sont souvent désorganisées et visuelles. L'OCR extrait les lettres écrites à la main, puis l'humain ou l'IA doit associer chaque idée textuelle à une catégorie thématique pour créer des lignes et des colonnes logiques.
#
# Un tutoriel vidéo sur la cuisineMéthode de transformation : L'Analyse Vidéo Multimodale (extraction des images clés pour les ingrédients visuels + extraction de l'audio converti en texte pour les instructions).Format structuré obtenu : Un tableau avec les colonnes :
# Justification : Une vidéo mélange des images, du mouvement et du son. Extraire les sous-titres (audio) permet d'avoir la liste des étapes, tandis que l'analyse des images permet de valider visuellement les ustensiles et ingrédients utilisés pour les lister proprement sous forme de recette structurée.Avez-vous besoin d'un exemple de code Python simple pour tester l'extraction de texte à partir d'une image (OCR) si vous avez des notes de cours à numériser ?

# %%
#exercice8


import pandas as pd

df_train = pd.read_csv('C:/Users/hp/Desktop/DI_BOOTCAMP/week2/Day1/exerciceXP/train.csv')
df_train.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#exercice9 

import pandas as pd

# 
donnees = {
    'Nom': ['Emmanuel', 'Grace', 'Emma'],
    'Âge': [22, 24, 21],
    'Note_Python': [18.5, 15.0, 19.0]
}
df_simple = pd.DataFrame(donnees)

print("--- DATAFRAME CRÉÉ ---")
print(df_simple)


chemin_excel = 'C:/Users/hp/Desktop/DI_BOOTCAMP/week2/Day1/exerciceXP/etudiants.xlsx'
chemin_json = 'C:/Users/hp/Desktop/DI_BOOTCAMP/week2/Day1/exerciceXP/etudiants.json'


df_simple.to_excel(chemin_excel, index=False)
print(f"\n Fichier Excel exporté avec succès sur le Bureau : {chemin_excel}")

# 3. Exportation au format JSON
df_simple.to_json(chemin_json, orient='records', indent=4)
print(f" Fichier JSON exporté avec succès sur le Bureau : {chemin_json}")
# Out:
# --- DATAFRAME CRÉÉ ---
#         Nom  Âge  Note_Python
# 0  Emmanuel   22         18.5
# 1     Grace   24         15.0
# 2      Emma   21         19.0
#
#  Fichier Excel exporté avec succès sur le Bureau : C:/Users/hp/Desktop/DI_BOOTCAMP/week2/Day1/exerciceXP/etudiants.xlsx
#  Fichier JSON exporté avec succès sur le Bureau : C:/Users/hp/Desktop/DI_BOOTCAMP/week2/Day1/exerciceXP/etudiants.json

# %%
#exercice10 
import pandas as pd 
df_posts =
